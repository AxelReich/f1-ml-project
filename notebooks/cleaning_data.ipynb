# %% [markdown]
# <h1><bold> Cleaning the data from raw </bold</h1>

# %%
from pathlib import Path
import pandas as pd

# Show all columns/rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Build the path (simple relative example)
csv_path = Path("../data/raw/2022_race_results.csv")

try:
    # Read the CSV file
    df = pd.read_csv(csv_path)

    # Print entire DataFrame (first 5 rows but ALL columns)
    print(df)

except FileNotFoundError:
    print(f"File not found at: {csv_path}")
# Out:
#      DriverNumber BroadcastName Abbreviation         DriverId  \
# 0              16     C LECLERC          LEC          leclerc
# 1              55       C SAINZ          SAI            sainz
# 2              44    L HAMILTON          HAM         hamilton
# 3              63     G RUSSELL          RUS          russell
# 4              20   K MAGNUSSEN          MAG  kevin_magnussen
# 5              77      V BOTTAS          BOT           bottas
# 6              31        E OCON          OCO             ocon
# 7              22     Y TSUNODA          TSU          tsunoda
# 8              14      F ALONSO          ALO           alonso
# 9              24        G ZHOU          ZHO             zhou
# 10             47  M SCHUMACHER          MSC  mick_schumacher
# 11             18      L STROLL          STR           stroll
# 12             23       A ALBON          ALB            albon
# 13              3   D RICCIARDO          RIC        ricciardo
# ...
